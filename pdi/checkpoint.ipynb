# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %%
PATH = "images/"
AC_VALHALA = os.path.join(PATH, "valhala2.webp")

# %%
x = np.uint8(250)
y = np.uint8(10)
z = x + y
print(x)
print(y)
print(z)
# Out:
# 250
# 10
# 4
# /tmp/ipykernel_56459/1954325047.py:3: RuntimeWarning: overflow encountered in scalar add
#   z = x + y

# %%
img = cv2.imread(AC_VALHALA, cv2.IMREAD_COLOR)
val = 50
img2 = img + val
img3 = cv2.add(img, val)

# %%
def bgr2rgb(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(18,10))
plt.subplot(221); plt.title("IMG"); plt.imshow(bgr2rgb(img))
plt.subplot(222); plt.title("IMG 2"); plt.imshow(bgr2rgb(img2))
plt.subplot(223); plt.title("IMG"); plt.imshow(bgr2rgb(img))
plt.subplot(224); plt.title("IMG 3"); plt.imshow(bgr2rgb(img3))

# %%
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
